# %% [markdown]
# <a href="https://colab.research.google.com/github/marcoantoniobarbosacardoso-boop/U-Void/blob/main/YOOOYOOYOOYOOOOOOO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Aula de programação e algorítmo
# Out:
#   File "/tmp/ipykernel_1410/800241224.py", line 1
#     Aula de programação e algorítmo
#          ^
# SyntaxError: invalid syntax

# %%
lado1 = 4

lado2 = 5.5

#calculo da área

área = lado1 * lado2

#calculo da área de um quadrado

áreaquadrada = lado1 * lado1

áreaquadrada2 = lado2 * lado2

áreaseilá = lado1 * lado2 *lado2 * lado1

áreadosmanos = lado1 * lado1 *lado1 + lado2 - lado1 *lado2 * lado1 + lado2 *lado1

# %%
print (área)
# Out:
# 22.0

# %%
print (áreaquadrada)
# Out:
# 16

# %%
print (áreaquadrada2)
# Out:
# 30.25

# %%
print (áreaseilá)
# Out:
# 484.0

# %%
print (áreadosmanos)
# Out:
# 3.5

# %%
input ("aRE YoU GAy???7?7")
# Out:
# aRE YoU GAy???7?7YAAAAAARRRR
# 'YAAAAAARRRR'

# %%
namezinho = "babylonios"

# %%
ME = "mar"
idade = "bruh11"
altura = "burururur"

# %%
print (f"nome: {ME}, idade: {idade}, altura: {altura}")
# Out:
# nome: mar, idade: bruh11, altura: burururur
