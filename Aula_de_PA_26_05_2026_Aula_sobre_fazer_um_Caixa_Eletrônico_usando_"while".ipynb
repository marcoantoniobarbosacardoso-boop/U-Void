# %% [markdown]
# <a href="https://colab.research.google.com/github/marcoantoniobarbosacardoso-boop/U-Void/blob/main/Aula_de_PA_26_05_2026_Aula_sobre_fazer_um_Caixa_Eletr%C3%B4nico_usando_%22while%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Projeto caixa eletrônico.

# Você foi contatado para fazer um sistema simples de caixa eletrônico.

# O programa com um saldo inicial de R$1000,00 e permitir que o usuário escolha diferentes operações até decidir sair do sistema.

# Ver saldo
# Depositar
# Sacar dinheiro
# Sair

# Regras:

# Quando depositar somar ao saldo anterior;
# Quando sacar subtrair do saldo anterior;
# Mostrar o saldo do usuário

# Começando... #


Número = 1000,00

print ("Enredo: Um homem chega até o banco e deposita R$100,00 em seu saldo bancário que é R$1000,00, então, no próximo dia ele retira R$50,00 de seu saldo bancário.")
print ("")

# Calculadora Simples:

# O programa  receber dois números e irá realizar uma das 4 operações matemáticas.

opção = ""
número_a = 0
número_b = 0

print ("------ MENU ------")
print ("")
print ("Opção 1: Depositar dinheiro")
print ("")
print ("Opção 2: Retirar dinheiro")
print ("")
print ("Opção 3: Sair")
print ("")
print ("======================")
print ("")

try:

  while opção != 3:
    opção = int (input("Digite a opção desejada ou 3 para sair. "))
    print ("")


    if opção == 1:
      número_a = float (input("Digite um número: "))
      print ("")
      número_b = float (input("Digite um número: "))
      print ("")
      print (f"Seu novo saldo é {número_a + número_b} ")
      print ("")

    elif opção == 2:
      número_a = float (input("Digite um número: "))
      print ("")
      número_b = float (input("Digite um número: "))
      print ("")
      print (f"Seu novo saldo é: {número_a - número_b} ")
      print ("")

except:
  print ("Digite apenas número de 1 a 2.")
# Out:
# Enredo: Um homem chega até o banco e deposita R$100,00 em seu saldo bancário que é R$1000,00, então, no próximo dia ele retira R$50,00 de seu saldo bancário.
#
# ------ MENU ------
#
# Opção 1: Depositar dinheiro
#
# Opção 2: Retirar dinheiro
#
# Opção 3: Sair
#
# ...
#
# Digite a opção desejada ou 3 para sair.
# Digite apenas número de 1 a 2.

# %%
11
5
# Calculadora Simples:

# O programa  receber dois números e irá realizar uma das 4 operações matemáticas.

opção = ""
número_a = 0
número_b = 0

print ("------ MENU ------")
print ("")
print ("Opção 1: Somar")
print ("Opção 2: Subtrair")
print ("Opção 3: Multiplicação")
print ("Opção 4: Divisão")
print ("Opção 5: Sair")
print ("======================")
print ("")

try:

  while opção != 5:
    opção = int (input("Digite a opção desejada ou 5 para sair. "))
    print ("")


    if opção == 1:
      número_a = float (input("Digite um número: "))
      print ("")
      número_b = float (input("Digite um número: "))
      print ("")
      print (f"O total da operação de {número_a} + {número_b} é igual a: {número_a + número_b} ")
      print ("")

    elif opção == 2:
      número_a = float (input("Digite um número: "))
      print ("")
      número_b = float (input("Digite um número: "))
      print ("")
      print (f"O total da operação de {número_a} - {número_b} é igual a: {número_a - número_b} ")
      print ("")

    elif opção == 3:
      número_a = float (input("Digite um número: "))
      print ("")
      número_b = float (input("Digite um número: "))
      print ("")
      print (f"O total da operação de {número_a} x {número_b} é igual a: {número_a * número_b} ")
      print ("")

    elif opção == 4:
      número_a = float (input("Digite um número: "))
      print ("")
      número_b = float (input("Digite um número: "))
      print ("")
      print (f"O total da operação de {número_a} / {número_b} é igual a: {número_a / número_b}")
      print ("")

except:
  print ("Digite apenas número de 1 a 5.")
# Out:
# ------ MENU ------
#
# Opção 1: Somar
# Opção 2: Subtrair
# Opção 3: Multiplicação
# Opção 4: Divisão
# Opção 5: Sair
# ...
#
# Digite a opção desejada ou 5 para sair. 1
#
# Digite um número: 1
#
# Digite um número: 1
#
# O total da operação de 1.0 + 1.0 é igual a: 2.0
#
# Digite a opção desejada ou 5 para sair. 1
#
# Digite um número:
# Digite apenas número de 1 a 5.

# %%
import random

a = random.random()

print (a)
# Out:
# 0.6013149197717873

# %%
import random

a = random.randint (0, 10)

print (a)
# Out:
# 4
