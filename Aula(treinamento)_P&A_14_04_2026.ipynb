# %% [markdown]
# <a href="https://colab.research.google.com/github/marcoantoniobarbosacardoso-boop/U-Void/blob/main/Aula(treinamento)_P%26A_14_04_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Questão 1)

número = int (input ("Digite um número de 0-10: "))

if número == 0:
  print (f"Este número é par.")

elif número == 1:
  print (f"Este número é ímpar.")

elif número == 2:
  print (f"Este número é par.")

elif número == 3:
  print (f"Este número é ímpar.")

elif número == 4:
  print (f"Este número é par.")

elif número == 5:
  print (f"Este número é ímpar.")

elif número == 6:
  print (f"Este número é par.")

elif número == 7:
  print (f"Este número é ímpar.")

elif número == 8:
  print (f"Este número é par.")

elif número == 9:
  print (f"Este número é ímpar.")

elif número == 10:
  print (f"Este número é par.")
# Out:
# Digite um número de 0-10: 10
# Este número é par.

# %%
# Questão 2)

número1 = int (input ("Digite qualquer número: "))
número2 = int (input ("Digite qualquer número: "))

if número1 < número2:
  print (f"{número1} é menor que {número2}")

elif número1 == número2:
  print (f"{número1} é igual à {número2}")

else:
  print (f"{número1} é maior que {número2}")
# Out:
# Digite qualquer número: 10
# Digite qualquer número: 10
# 10 é igual à 10

# %%
# Questão 3)

Nota = int (input ("Digite sua nota: "))

if Nota >= 7:
  print (f"Você foi promovido.")

elif Nota >= 5:
  print (f"Você está para recuperação.")

elif Nota < 5:
  print (f"Reprovado.")
# Out:
# Digite sua nota: 7
# Você foi promovido.

# %%
# Questão 4)

idade = int (input ("Digite sua idade: "))

if idade <= 12:
  print (f"Você é uma criança.")

elif idade < 17:
  print (f"Você é um adolescente.")

elif idade == 17:
  print (f"Você é um adolescente.")

elif idade <= 59:
  print (f"Você é um adulto.")

elif idade > 59:
  print (f"Você é um idoso.")
# Out:
# Digite sua idade: 6000
# Você é um idoso.

# %%
# Questão 5

código = int (input ("Digite a sua senha (apenas números): "))

if código == 67_67:

  print (f"Senha correta.")

else:
  print (f"Senha incorreta.")
# Out:
# Digite a sua senha (apenas números): 1121292121
# Senha incorreta.
